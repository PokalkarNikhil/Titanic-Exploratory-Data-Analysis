# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### Input the Dataset

# %%
df=pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 1-Data Exploration

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 2-Data Cleaning

# %%
#Null Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Removing Column

# %%
df=df.drop("Cabin",axis=1)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### Duplicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 3-Data Analysis

# %%
df["PassengerId"].count()
# Out:
# np.int64(891)

# %% [markdown]
# ### There are 891 passengers present in the ship

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ### most of the people died in the incident

# %%
a=pd.DataFrame(df.groupby("Sex")["Survived"].mean()*100)
a
# Out:
#          Survived
# Sex
# female  74.203822
# male    18.890815

# %% [markdown]
# ### Female Survived more in the incident

# %%
b=pd.DataFrame(df.groupby("Pclass")["Survived"].mean()*100)
b
# Out:
#          Survived
# Pclass
# 1       62.962963
# 2       47.282609
# 3       24.236253

# %% [markdown]
# ### Passenger from the class 1 have survived more than class 2 & 3

# %% [markdown]
# ### Bining

# %%
bins=[0,18,36,72]
label=["Child","Adult","Old"]
df["Agegroup"]=pd.cut(df['Age'],bins=bins,labels=label)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked Agegroup
# 0      0         A/5 21171   7.2500        S    Adult
# 1      0          PC 17599  71.2833        C      Old
# 2      0  STON/O2. 3101282   7.9250        S    Adult
# 3      0            113803  53.1000        S    Adult
# ...

# %%
c=pd.DataFrame(df.groupby("Agegroup")["Survived"].mean()*100)
c
# Out:
#            Survived
# Agegroup
# Child     50.359712
# Adult     35.906643
# Old       36.787565

# %% [markdown]
# ### child survived more in the incident

# %%
df.sort_values(by="Fare",ascending=False).head(10) # To Check high fare have high survived or not
# Out:
#      PassengerId  Survived  Pclass  \
# 679          680         1       1
# 258          259         1       1
# 737          738         1       1
# 88            89         1       1
# 438          439         0       1
# 341          342         1       1
# 27            28         0       1
# 742          743         1       1
# 311          312         1       1
# 299          300         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 679               Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 258                                 Ward, Miss. Anna  female  35.0      0
# 737                           Lesurer, Mr. Gustave J    male  35.0      0
# 88                        Fortune, Miss. Mabel Helen  female  23.0      3
# 438                                Fortune, Mr. Mark    male  64.0      1
# 341                   Fortune, Miss. Alice Elizabeth  female  24.0      3
# ...

# %% [markdown]
# ### The customers who payed more has survived

# %%
df["Family_Members"]=df["SibSp"]+df["Parch"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked Agegroup  Family_Members
# 0      0         A/5 21171   7.2500        S    Adult               1
# 1      0          PC 17599  71.2833        C      Old               1
# 2      0  STON/O2. 3101282   7.9250        S    Adult               0
# ...

# %%
df["Family_Members"].sum()
# Out:
# np.int64(806)

# %% [markdown]
# ### 90 percent of passenger were family members

# %%
df["Name"].str.contains("Mr.").sum()
# Out:
# np.int64(647)

# %% [markdown]
# ### 70% to 80% of passenger were married

# %% [markdown]
# ### 4- Data Visulization

# %%
sns.barplot(x="Sex",y="Survived",data=a,color="blue",edgecolor="black")
plt.title(" No of Males and Females Survived ")
plt.xlabel("Gender")
plt.ylabel(" Survived Rate")
plt.show()

# %%
sns.barplot(x="Pclass",y="Survived",data=b,color="orange",edgecolor="black")
plt.title(" Pclass wise survival rate ")
plt.xlabel("Pclass")
plt.ylabel(" Survived Rate")
plt.show()

# %%
sns.barplot(x="Agegroup",y="Survived",data=c,color="yellow",edgecolor="black")
plt.title(" Agegroup wise survival rate ")
plt.xlabel("Agegroup")
plt.ylabel(" Survived Rate")
plt.show()

# %% [markdown]
# ### 5-Creating Dashboards

# %%
plt.figure(figsize=(20,10))
plt.title("Dash_Board")
plt.subplot(2,3,1)
sns.countplot(x="Survived",data=df)
plt.subplot(2,3,2)
sns.countplot(x="Sex",hue="Survived",data=df)
plt.subplot(2,3,3)
sns.countplot(x="Pclass",hue="Survived",data=df)
plt.subplot(2,3,4)
sns.countplot(x="Agegroup",hue="Survived",data=df)
plt.subplot(2,3,5)
sns.scatterplot(x="Age",y="Fare",hue="Survived",data=df)
plt.subplot(2,3,6)
sns.boxplot(x="Fare",data=df)
plt.show()

# %% [markdown]
# ### 6- Data story telling

# %% [markdown]
# 1. Most people have died in the incident
# 2. Most of the males have died in the incident
# 3. Most of people are survived from passenger class 1
# 4. Survival rate of the children are more as compared to adults and old
# 5. People who are paying more have the survival chance more
# 6. Around 20 passenger are paying more than average people
